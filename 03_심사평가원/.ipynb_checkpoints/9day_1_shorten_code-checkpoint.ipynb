# %%
import pandas as pd

# %%
file_path = './files_new/df_20TABLE_kor_명세서일반내역.xlsx'
df_20TABLE_org = pd.read_excel(file_path)
df_20TABLE_org
# Out:
#       명세서 연결코드  수진자고유번호  청구형태코드  청구구분코드  서식코드  연령군      추출확률      샘플가중치  \
# 0            1      169       3       0     3   13  0.030001  33.332599
# 1            2      183       3       0     8   15  0.030000  33.332882
# 2            3       23       3       0     3    3  0.030000  33.332920
# 3            4       96       3       0     5   14  0.030000  33.333002
# 4            5       28       3       0     3    4  0.030001  33.332721
# ...        ...      ...     ...     ...   ...  ...       ...        ...
# 5626      5627      178       3       0     5    2  0.030000  33.332844
# 5627      5628      295       3       0     3    4  0.030001  33.332721
# 5628      5629      246       3       0     3    1  0.030000  33.333050
# 5629      5630      253       3       0     3   10  0.030000  33.332913
# 5630      5631      250       3       0     3   13  0.030001  33.332599
#
#       수진자연령  성별구분코드  ...  내원일수 심결요양급여비용총액 심결본인부담금  심결보험자부담금  수술여부  특정기호구분코드  \
# ...

# %%
df_20TABLE_org[['수진자연령', '요양개시일자', '심결본인부담금']]
# Out:
#       수진자연령    요양개시일자  심결본인부담금
# 0        62  20130108     2800
# 1        74  20130212      500
# 2        14  20130222     1300
# 3        68  20130608     7900
# 4        19  20131128     2800
# ...     ...       ...      ...
# 5626      9  20131001     3900
# 5627     20  20130423     3500
# 5628      4  20130112     2900
# 5629     47  20130401     2800
# 5630     65  20130503     5600
#
# [5631 rows x 3 columns]

# %%
df_month_age = pd.DataFrame({'수진자연령':df_20TABLE_org['수진자연령'],
                             '요양개시일자':df_20TABLE_org['요양개시일자'],
                             '심결본인부담금':df_20TABLE_org['심결본인부담금']})

df_month_age
# Out:
#       수진자연령    요양개시일자  심결본인부담금
# 0        62  20130108     2800
# 1        74  20130212      500
# 2        14  20130222     1300
# 3        68  20130608     7900
# 4        19  20131128     2800
# ...     ...       ...      ...
# 5626      9  20131001     3900
# 5627     20  20130423     3500
# 5628      4  20130112     2900
# 5629     47  20130401     2800
# 5630     65  20130503     5600
#
# [5631 rows x 3 columns]

# %%
for i in range(0, 100, 10):
        j = i + 10
        globals()[f'df_{i}'] = df_month_age[(df_month_age['수진자연령'] >= i) & (df_month_age['수진자연령'] < j)]
        globals()[f'df_{i}'] = globals()[f'df_{i}'].reset_index(drop = True)
        globals()[f'df_{i}']['연령대'] = f'{i}대'
        
df_0
# Out:
#      수진자연령    요양개시일자  심결본인부담금 연령대
# 0        3  20131211     2900  0대
# 1        6  20130129     2800  0대
# 2        3  20130130     2700  0대
# 3        6  20130130     6500  0대
# 4        6  20130502     2800  0대
# ..     ...       ...      ...  ..
# 664      5  20131207     2000  0대
# 665      6  20130201     2800  0대
# 666      3  20130622     2000  0대
# 667      9  20131001     3900  0대
# 668      4  20130112     2900  0대
#
# [669 rows x 4 columns]
