# %% [markdown]
# # 전입사유
# ### # 데이터 출처 :
#   * https://kosis.kr/publication/publicationThema.do
#   * 국내인구통계
#     - 4. 국내인구이동통계연보
#       + 18. 시도 및 전입사유, 연령별 1인 이동건수

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2021

# %%
# 데이터 불러오기

df_2021 = pd.read_excel("./2021.xlsx",
                        sheet_name = "표17",
                        header=5,
                       usecols = "A:C,E:F"
                       ) # 사용할 sheet 이름 지정
    
df_2021
# Out:
#                 연령\n \n 전입사유 Unnamed: 1      총합계        20대       30대
# 0                        NaN        NaN      NaN        NaN       NaN
# 1                        NaN        NaN    Total        NaN       NaN
# 2                         전체          계  3799586  1275403.0  869207.0
# 3                        NaN         직업  1181029   523028.0  286163.0
# 4                        NaN         가족  1038023   317876.0  257006.0
# 5                        NaN         주택   856748   188642.0  207916.0
# 6                        NaN         교육   174538   104934.0    5964.0
# 7                        NaN       주거환경   177804    63636.0   43767.0
# 8                        NaN       자연환경    53674     4850.0    5656.0
# 9                        NaN         기타   317770    72437.0   62735.0
# 10                        서울          계   774163   307397.0  198594.0
# 11                       NaN         직업   251041   134652.0   64158.0
# 12                       NaN         가족   182368    52423.0   55109.0
# 13                       NaN         주택   178717    50002.0   49188.0
# 14                       NaN         교육    47286    34194.0    1936.0
# 15                       NaN       주거환경    43730    18818.0   12868.0
# 16                       NaN       자연환경     2860      398.0     441.0
# 17                       NaN         기타    68161    16910.0   14894.0
# 18                        부산          계   239977    82916.0   53908.0
# 19                       NaN         직업    68735    31374.0   16672.0
# 20                       NaN         가족    66304    19859.0   17209.0
# 21                       NaN         주택    57921    12505.0   12656.0
# 22                       NaN         교육    13597     9604.0     377.0
# 23                       NaN       주거환경    12947     4979.0    3000.0
# 24                       NaN       자연환경     2158      211.0     246.0
# 25                       NaN         기타    18315     4384.0    3748.0

# %%
# 20대 30대 컬럼만 추출

df_2021_seoul = df_2021.loc[11:17, ["Unnamed: 1","20대","30대"]]

df_2021_seoul
# Out:
#    Unnamed: 1       20대      30대
# 11         직업  134652.0  64158.0
# 12         가족   52423.0  55109.0
# 13         주택   50002.0  49188.0
# 14         교육   34194.0   1936.0
# 15       주거환경   18818.0  12868.0
# 16       자연환경     398.0    441.0
# 17         기타   16910.0  14894.0

# %%
# 인덱스를 사유로 변경

df_2021_seoul_SetIndex = df_2021_seoul.set_index(keys=['Unnamed: 1'], inplace=False, drop=True)

df_2021_seoul_SetIndex
# Out:
#                  20대      30대
# Unnamed: 1
# 직업          134652.0  64158.0
# 가족           52423.0  55109.0
# 주택           50002.0  49188.0
# 교육           34194.0   1936.0
# 주거환경         18818.0  12868.0
# 자연환경           398.0    441.0
# 기타           16910.0  14894.0

# %%
import pandas as pd                # 데이터를 저장하고 처리하는 패키지
import matplotlib as mpl           # 그래프를 그리는 패키지
import matplotlib.pyplot as plt    # 그래프를 그리는 패키지

plt.rc('font', family = 'Malgun Gothic')

# %%
# 시각화
ax = df_2021_seoul_SetIndex.plot(kind='bar', title='2021년 서울 전입사유', figsize=(30, 15), legend=True, fontsize=30)
ax.set_xlabel('사유', fontsize=30)          # x축 정보 표시
ax.set_ylabel('인구수', fontsize=30)     # y축 정보 표시
ax.legend(['20대', "30대"], fontsize=30)    # 범례 지정

# %% [markdown]
# ## 2020 년도

# %%
# 2020 데이터 불러오기

df_2020 = pd.read_excel("./2020.xlsx",
                        sheet_name = "표17",
                        header=5,
                       usecols = "A:C,E:F"
                       ) # 사용할 sheet 이름 지정

# 20대 30대 컬럼만 추출

df_2020_seoul = df_2020.loc[11:17, ["Unnamed: 1","20대","30대"]]

# 인덱스를 사유로 변경

df_2020_seoul_SetIndex = df_2020_seoul.set_index(keys=['Unnamed: 1'], inplace=False, drop=True)

# 시각화

ax = df_2020_seoul_SetIndex.plot(kind='bar', title='2020년 서울 전입사유', figsize=(30, 15), legend=True, fontsize=30)
ax.set_xlabel('사유', fontsize=30)          # x축 정보 표시
ax.set_ylabel('인구수', fontsize=30)     # y축 정보 표시
ax.legend(['20대', "30대"], fontsize=30)    # 범례 지정

# %% [markdown]
# ## 경기도 2021년도 전입 사유

# %%
# 2021 데이터 불러오기

df_2021 = pd.read_excel("./2021.xlsx",
                        sheet_name = "표17 (계속)",
                        header=5,
                       usecols = "A:C,E:F"
                       ) # 사용할 sheet 이름 지정

df_2021
# Out:
#                   연령\n \n 전입사유 Unnamed: 1     총합계      20대      30대
# 0                          NaN        NaN     NaN      NaN      NaN
# 1                          NaN        NaN   Total      NaN      NaN
# 2                           대구          계  155926  51660.0  35043.0
# 3                          NaN         직업   42945  19466.0  10504.0
# 4                          NaN         가족   46220  14598.0  11352.0
# ..                         ...        ...     ...      ...      ...
# 117                        NaN         주택   11123   1915.0   2277.0
# 118                        NaN         교육    1321    503.0    100.0
# 119                        NaN       주거환경    2060    628.0    458.0
# 120                        NaN       자연환경    2054    260.0    362.0
# 121                        NaN         기타    3891    694.0    694.0
#
# [122 rows x 5 columns]

# %%
# 20대 30대 경기도 컬럼만 추출

df_2021_gk = df_2021.loc[50:57, ["Unnamed: 1","20대","30대"]]

df_2021_gk
# Out:
#    Unnamed: 1       20대       30대
# 50          계  304802.0  237679.0
# 51         직업  127572.0   75478.0
# 52         가족   81940.0   71368.0
# 53         주택   46342.0   60546.0
# 54         교육   16064.0     905.0
# 55       주거환경   13725.0   10994.0
# 56       자연환경    1047.0    1370.0
# 57         기타   18112.0   17018.0

# %%
# 인덱스를 사유로 변경

df_2021_gk_SetIndex = df_2021_gk.set_index(keys=['Unnamed: 1'], inplace=False, drop=True)

# 시각화

ax = df_2021_gk_SetIndex.plot(kind='bar', title='2021년 경기도 전입사유', figsize=(30, 15), legend=True, fontsize=30)
ax.set_xlabel('사유', fontsize=30)          # x축 정보 표시
ax.set_ylabel('인구수', fontsize=30)     # y축 정보 표시
ax.legend(['20대', "30대"], fontsize=30)    # 범례 지정

# %% [markdown]
# ## 경기도 2020년도 전입 사유

# %%
# 2020 데이터 불러오기

df_2020 = pd.read_excel("./2020.xlsx",
                        sheet_name = "표17 (계속)",
                        header=5,
                       usecols = "A:C,E:F"
                       ) # 사용할 sheet 이름 지정

# 20대 30대 경기도 컬럼만 추출

df_2020_gk = df_2020.loc[50:57, ["Unnamed: 1","20대","30대"]]

# 인덱스를 사유로 변경

df_2020_gk_SetIndex = df_2020_gk.set_index(keys=['Unnamed: 1'], inplace=False, drop=True)

df_2020_gk_SetIndex

# 시각화

ax = df_2020_gk_SetIndex.plot(kind='bar', title='2020년 경기도 전입사유', figsize=(30, 15), legend=True, fontsize=30)
ax.set_xlabel('사유', fontsize=30)          # x축 정보 표시
ax.set_ylabel('인구수', fontsize=30)     # y축 정보 표시
ax.legend(['20대', "30대"], fontsize=30)    # 범례 지정

# %%
# 각 데이터를 순서대로 df0, df1, df2, df3에 저장

df0 = df_2020_gk_SetIndex
df1 = df_2021_gk_SetIndex
df2 = df_2020_seoul_SetIndex
df3 = df_2021_seoul_SetIndex

# final_df에 df0, df1, df2, df3를 concat 함수를 이용하여 열기준과 inner join으로 합침

final_df = pd.concat([df0, df1,df2, df3],axis=1, join='inner')
final_df
# Out:
#                  20대      30대       20대      30대       20대      30대       20대  \
# Unnamed: 1
# 직업          114764.0  72559.0  127572.0  75478.0  130124.0  66527.0  134652.0
# 가족           84120.0  74407.0   81940.0  71368.0   57206.0  64402.0   52423.0
# 주택           45540.0  58614.0   46342.0  60546.0   52748.0  52942.0   50002.0
# 교육           14334.0   1121.0   16064.0    905.0   34804.0   2192.0   34194.0
# 주거환경         13346.0  10990.0   13725.0  10994.0   18679.0  13157.0   18818.0
# 자연환경          1015.0   1374.0    1047.0   1370.0     516.0    541.0     398.0
# 기타           15382.0  14970.0   18112.0  17018.0   16013.0  14637.0   16910.0
#
#                 30대
# Unnamed: 1
# 직업          64158.0
# 가족          55109.0
# 주택          49188.0
# 교육           1936.0
# 주거환경        12868.0
# 자연환경          441.0
# 기타          14894.0

# %%
# 각 해당연도와 지역으로 구분하여 막대그래프 그리기

final_df.iloc[:, [0,1]].plot(kind='bar', title='2020년 경기도 전입사유', figsize=(30, 15), legend=True, fontsize=30)
final_df.iloc[:, [2,3]].plot(kind='bar', title='2021년 경기도 전입사유', figsize=(30, 15), legend=True, fontsize=30)
final_df.iloc[:, [4,5]].plot(kind='bar', title='2020년 서울 전입사유', figsize=(30, 15), legend=True, fontsize=30)
final_df.iloc[:, [6,7]].plot(kind='bar', title='2021년 서울 전입사유', figsize=(30, 15), legend=True, fontsize=30)

plt.show()
