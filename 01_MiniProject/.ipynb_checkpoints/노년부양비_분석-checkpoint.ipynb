# %%
import pandas as pd
file_path = "./10년간_지역별_고령인구_비율.csv"
df = pd.read_csv(file_path)

# %%
df
# Out:
#          지역  고령인구비율<br>(A÷B×100) (%)  고령인구비율<br>(A÷B×100) (%).1  \
# 0     서울특별시                     10.8                       11.5
# 1     부산광역시                     12.5                       13.3
# 2     대구광역시                     10.9                       11.6
# 3     인천광역시                      9.4                        9.8
# 4     광주광역시                      9.9                       10.3
# 5     대전광역시                      9.4                        9.8
# 6     울산광역시                      7.5                        7.9
# 7   세종특별자치시                     15.2                       14.7
# 8       경기도                      9.4                        9.8
# 9       강원도                     15.7                       16.2
# 10     충청북도                     13.7                       14.1
# 11     충청남도                     15.3                       15.6
# 12     전라북도                     16.2                       16.7
# 13     전라남도                     19.2                       19.6
# 14     경상북도                     16.2                       16.8
# 15     경상남도                     12.5                       12.9
# 16  제주특별자치도                     13.0                       13.4
#
#     고령인구비율<br>(A÷B×100) (%).2  고령인구비율<br>(A÷B×100) (%).3  \
# 0                        12.0                       12.6
# 1                        14.0                       14.6
# 2                        12.2                       12.7
# 3                        10.3                       10.7
# 4                        10.8                       11.3
# 5                        10.3                       10.9
# 6                         8.3                        8.8
# 7                        12.7                       10.6
# 8                        10.2                       10.5
# 9                        16.6                       16.9
# 10                       14.5                       14.8
# 11                       16.0                       16.4
# 12                       17.2                       17.8
# 13                       20.1                       20.5
# 14                       17.3                       17.7
# 15                       13.4                       13.8
# 16                       13.6                       13.8
#
#     고령인구비율<br>(A÷B×100) (%).4  고령인구비율<br>(A÷B×100) (%).5  \
# 0                        13.0                       13.8
# 1                        15.3                       16.3
# 2                        13.2                       14.0
# 3                        11.0                       11.7
# 4                        11.7                       12.4
# 5                        11.3                       12.0
# 6                         9.3                       10.0
# 7                        10.0                        9.6
# 8                        10.8                       11.4
# 9                        17.2                       18.1
# 10                       15.1                       15.8
# 11                       16.7                       17.1
# 12                       18.3                       18.9
# 13                       21.0                       21.5
# 14                       18.2                       19.0
# 15                       14.2                       14.9
# 16                       13.9                       14.2
#
#     고령인구비율<br>(A÷B×100) (%).6  고령인구비율<br>(A÷B×100) (%).7  \
# 0                        14.4                       15.2
# 1                        17.1                       18.2
# 2                        14.7                       15.6
# 3                        12.3                       13.0
# 4                        12.8                       13.4
# 5                        12.7                       13.5
# 6                        10.7                       11.5
# 7                         9.3                        9.4
# 8                        11.9                       12.5
# 9                        18.8                       19.6
# 10                       16.4                       17.1
# 11                       17.5                       18.2
# 12                       19.5                       20.4
# 13                       21.9                       22.6
# 14                       19.8                       20.6
# 15                       15.5                       16.3
# 16                       14.4                       15.0
#
#     고령인구비율<br>(A÷B×100) (%).8  고령인구비율<br>(A÷B×100) (%).9
# 0                        16.1                       16.8
# 1                        19.4                       20.4
# 2                        16.6                       17.5
# 3                        14.0                       14.8
# 4                        14.2                       14.8
# 5                        14.4                       15.2
# 6                        12.6                       13.6
# 7                         9.8                       10.1
# 8                        13.2                       13.9
# 9                        20.7                       21.7
# 10                       18.0                       18.9
# 11                       19.1                       19.8
# 12                       21.4                       22.3
# 13                       23.5                       24.3
# 14                       21.7                       22.7
# 15                       17.4                       18.4
# 16                       15.7                       16.3

# %%
import pandas as pd
file_path = "./Young_pop.csv"
df1 = pd.read_csv(file_path)

# %%
df1
# Out:
#     지역    청년인구  버스터미널   철도역    공항  초등학교   중학교  고등학교      지수(점) 등급  ...  \
# 0   강원   56404   32.9  32.9  32.9  36.9  56.0  71.4  79.117219  E  ...
# 1   경기  579851   25.0  25.0  25.0  19.2  28.5  36.5  81.262092  C  ...
# 2   경남  128482   31.1  31.1  31.1  28.5  43.1  54.0  81.912194  C  ...
# 3   경북  100105   37.7  37.7  37.7  37.1  56.6  73.5  80.057274  D  ...
# 4   광주   66496   21.5  21.5  21.5  15.6  21.9  32.5  83.968337  A  ...
# 5   대구  104823   18.3  18.3  18.3  16.5  23.3  32.6  81.219598  C  ...
# 6   대전   64361   19.9  19.9  19.9  15.4  21.9  31.4  83.391163  B  ...
# 7   부산  146114   31.5  31.5  31.5  16.0  23.9  32.6  81.987617  C  ...
# 8   서울  489384   25.8  25.8  25.8  12.1  15.9  20.8  81.292265  C  ...
# 9   세종    9617   17.5  17.5  17.5  17.4  25.1  34.5  84.951890  A  ...
# 10  울산   40190   25.8  25.8  25.8  19.2  33.2  43.3  82.404533  B  ...
# 11  인천  138568   26.4  26.4  26.4  16.7  26.1  31.1  82.617784  B  ...
# 12  전남   71447   46.1  46.1  46.1  48.6  66.7  79.5  79.492157  D  ...
# 13  전북   69075   29.4  29.4  29.4  30.0  45.4  60.7  79.799290  D  ...
# 14  제주   31481   31.4  31.4  31.4  26.9  41.7  62.3  82.580625  B  ...
# 15  충남   84970   37.0  37.0  37.0  36.5  60.9  82.9  78.036222  E  ...
# 16  충북   60164   33.9  33.9  33.9  30.9  48.9  66.1  79.179578  D  ...
#
#     평균 휴양 만족 점수  건강 증진을 위해  휴양 및 휴식을 취하기 위해  취미 및 레포츠 활동을 위해  친목 활동을 위해   \
# 0          7.55       35.3             60.8              2.1         0.8
# 1          7.74       70.5             21.8              3.1           4
# 2          7.28       78.2             12.9              7.7         0.9
# 3          8.29       83.0              9.1              1.4         0.8
# 4          7.78       68.3             27.2                -         3.6
# 5          7.85       88.3              8.1                -         1.7
# 6          7.80       44.9             48.5              5.3         1.3
# 7          7.45       61.9             33.8              3.7         0.3
# 8          8.08       72.6             22.5              1.6         2.7
# 9          7.47       49.3             45.5              4.2           -
# 10         7.46       87.3              8.9              3.8           -
# 11         7.48       67.6             18.6              4.9         6.7
# 12         7.35       64.3             30.9                2         2.8
# 13         7.79       80.6             16.5              0.4           1
# 14         7.96       57.6             39.0              1.4         1.3
# 15         7.65       56.4             30.1              5.1         4.6
# 16         7.45       53.8             35.6              6.2         2.5
#
#     질병 치유를 위해  교육 학습을 위해   기타  지역별 강소기업 갯수  지역별 고령화 비율(%)
# 0           -          -    1          244           21.9
# 1         0.1        0.5    -         5107           14.0
# 2         0.3          -    -         1071           18.6
# 3         5.1        0.6    -          884           22.9
# 4           -        0.8    -          312           14.9
# 5           -        1.9    -          675           17.7
# 6           -          -    -          429           15.4
# 7         0.3          -    -          872           20.6
# 8         0.4        0.2    -         2991           17.0
# 9           -          1    -           52           10.1
# 10          -          -    -          263           13.9
# 11          -          -  2.2         1003           15.0
# 12          -          -    -          420           24.4
# 13        0.7        0.7    -          324           22.4
# 14          -          -  0.7           78           16.5
# 15        2.6        0.6  0.6          682           20.0
# 16        1.2          -  0.7          555           19.1
#
# [17 rows x 63 columns]

# %%
import pandas as pd
file_path = "./노년부양비.xlsx"
df1 = pd.read_excel(file_path, header = 2)

# %%
df1
# Out:
#       년도  2000  2001  2002  2003  2004  2005  2006  2007  2008  ...  2051  \
# 0  노년부양비  10.1  10.5  11.0  11.5  12.0  12.5  13.0  13.5  14.0  ...  78.7
#
#    2052  2053  2054  2055  2056  2057  2058  2059  2060
# 0  79.6  80.5  81.5  82.6  83.9  85.7  87.6  89.5  91.4
#
# [1 rows x 62 columns]

# %%
df1.astype('str')
# Out:
#       년도  2000  2001  2002  2003  2004  2005  2006  2007  2008  ...  2051  \
# 0  노년부양비  10.1  10.5  11.0  11.5  12.0  12.5  13.0  13.5  14.0  ...  78.7
#
#    2052  2053  2054  2055  2056  2057  2058  2059  2060
# 0  79.6  80.5  81.5  82.6  83.9  85.7  87.6  89.5  91.4
#
# [1 rows x 62 columns]

# %%
df2= df1.transpose()

df3 = df2.reset_index()

# %%
df2
# Out:
#           0
# 년도    노년부양비
# 2000   10.1
# 2001   10.5
# 2002   11.0
# 2003   11.5
# ...     ...
# 2056   83.9
# 2057   85.7
# 2058   87.6
# 2059   89.5
# 2060   91.4
#
# [62 rows x 1 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62 entries, 년도 to 2060
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       62 non-null     object
# dtypes: object(1)
# memory usage: 3.0+ KB

# %%
df3 = df2.reset_index()

# %%
df3.to_csv("노인부양비1.csv")

# %%
file_path = "./노인부양비1.csv"
df1 = pd.read_csv(file_path, header = 1)

# %%
df1.head()
# Out:
#    0    년도  노년부양비
# 0  1  2000   10.1
# 1  2  2001   10.5
# 2  3  2002   11.0
# 3  4  2003   11.5
# 4  5  2004   12.0

# %%
df4 = df1.drop(columns=["0"])

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      61 non-null     int64
#  1   노년부양비   61 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.1 KB

# %%
isin_filter = df4['년도'].isin([2000,2005,2010,2015,2020,2025,2030,2035,2040,2045,2050,2060])
df_old5 = df4[isin_filter]
print(df_old5)
# Out:
#       년도  노년부양비
# 0   2000   10.1
# 5   2005   12.5
# 10  2010   14.8
# 15  2015   17.5
# 20  2020   21.7
# 25  2025   29.3
# 30  2030   38.2
# 35  2035   48.4
# 40  2040   60.1
# 45  2045   69.0
# 50  2050   77.6
# 60  2060   91.4

# %%
df_old5
# Out:
#       년도  노년부양비
# 0   2000   10.1
# 5   2005   12.5
# 10  2010   14.8
# 15  2015   17.5
# 20  2020   21.7
# 25  2025   29.3
# 30  2030   38.2
# 35  2035   48.4
# 40  2040   60.1
# 45  2045   69.0
# 50  2050   77.6
# 60  2060   91.4

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df_old5["년도"], df_old5["노년부양비"])

# %%
import seaborn as sns

# %%
# 노년부양비 추세 그래프 그리기
plt.rcParams['font.family'] = 'Malgun Gothic' # 폰트설정
plt.rcParams['axes.unicode_minus'] = False    # 깨짐 방지 
ax = plt.subplots()
ax = sns.barplot(x = "년도", y = "노년부양비", data = df_old5)
plt.ylim([0, 100])
ax.set_title("미래의 노년부양비")
ax.set_xlabel("년도")
ax.set_ylabel("미래의 노년부양비")
plt.grid() 
plt.savefig('노년부양비') # 그래프 저장

# 노년부양비
# 노년부양비 : 생산가능인구(15~64세 인구) 100명이 부양해야 할 65세 인구의 수를 표시
# 노년부양비 = (65세 이상인구 / 15세~64세 인구) × 100
