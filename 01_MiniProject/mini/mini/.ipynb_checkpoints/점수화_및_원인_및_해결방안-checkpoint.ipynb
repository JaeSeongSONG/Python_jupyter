# %%
import pandas as pd

# %%
# 데이터 불렁오기
df = pd.read_csv('C:/Users/admin/Desktop/미니 프로젝트 1/활용한 데이터/3_시각화용(전처리 완료)/지역별_데이터_컬럼_수정.csv').drop(['Unnamed: 0'], axis = 1)

# %%
# 확인
df
# Out:
#     지역  경제활동인구(천명)    청년인구  강소기업수  선호_사업군의_사업체_수  매매가_전세가_비율  문화(축제건수+문화시설수)  \
# 0   강원        1688   56404    244          21858        65.5            1643
# 1   경기       14752  579851   5107         139570        64.3            6384
# 2   경남        3634  128482   1071          36450        64.8            2269
# 3   경북        2936  100105    884          30790        62.4            1712
# 4   광주        1558   66496    312          21030        69.8            1279
# 5   대구        2550  104823    675          29698        65.8             758
# 6   대전        1618   64361    429          20780        65.7             799
# 7   부산        3442  146114    872          41224        60.9            1380
# 8   서울       10652  489384   2991         204810        60.3            3720
# 9   세종         385    9617     52           3398        48.0             188
# 10  울산        1143   40190    263          13040        70.1             977
# ...

# %%
df.describe()
# Out:
#          경제활동인구(천명)           청년인구        강소기업수  선호_사업군의_사업체_수  매매가_전세가_비율  \
# count     17.000000      17.000000    17.000000      17.000000   17.000000
# mean    3336.764706  131854.823529   938.941176   40491.529412   63.688235
# std     3709.323128  156802.791069  1266.492917   51719.798915    5.170092
# min      385.000000    9617.000000    52.000000    3398.000000   48.000000
# 25%     1618.000000   60164.000000   312.000000   20780.000000   61.400000
# 50%     2012.000000   71447.000000   555.000000   22322.000000   65.500000
# 75%     3294.000000  128482.000000   884.000000   30790.000000   66.000000
# max    14752.000000  579851.000000  5107.000000  204810.000000   70.100000
#
#        문화(축제건수+문화시설수)  편의시설_평균_접근시간(분)  자연환경(휴양만족점수)     교통문화점수   고령화비율(%)
# count       17.000000        17.000000     17.000000  17.000000  17.000000
# mean      1720.235294        98.521765      7.672353  81.368824  17.905882
# ...
